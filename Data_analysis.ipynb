# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("sales.csv")
df.head()
# Out:
#   Product Region  Quantity  Price
# 0  Mobile  North         5  15000
# 1  Laptop  South         2  55000
# 2  Mobile   West         7  14000
# 3      TV  North         3  35000
# 4  Laptop   East         1  60000

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   10 non-null     object
#  1   Region    10 non-null     object
#  2   Quantity  10 non-null     int64
#  3   Price     10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#         Quantity         Price
# count  10.000000     10.000000
# mean    3.500000  32850.000000
# std     1.779513  18162.920103
# min     1.000000  14000.000000
# 25%     2.250000  15000.000000
# 50%     3.000000  33500.000000
# 75%     4.750000  48500.000000
# max     7.000000  60000.000000

# %%
df.isna().sum()
# Out:
# Product     0
# Region      0
# Quantity    0
# Price       0
# dtype: int64

# %%
df["Total_Sales"] = df["Quantity"] * df["Price"]
df.head()
# Out:
#   Product Region  Quantity  Price  Total_Sales
# 0  Mobile  North         5  15000        75000
# 1  Laptop  South         2  55000       110000
# 2  Mobile   West         7  14000        98000
# 3      TV  North         3  35000       105000
# 4  Laptop   East         1  60000        60000

# %%
sales_by_product = df.groupby("Product")["Total_Sales"].sum()
sales_by_product
# Out:
# Product
# Laptop    329000
# Mobile    290500
# TV        307000
# Name: Total_Sales, dtype: int64

# %%
sales_by_region = df.groupby("Region")["Total_Sales"].sum()
sales_by_region
# Out:
# Region
# East     268500
# North    180000
# South    221000
# West     257000
# Name: Total_Sales, dtype: int64

# %%
plt.figure(figsize=(8,5))
sales_by_product.plot(kind="bar")
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
plt.figure(figsize=(8,5))
sales_by_region.plot(kind="bar")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()
